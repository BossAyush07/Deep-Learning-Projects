# %% [markdown]
# <a href="https://colab.research.google.com/github/BossAyush07/Deep-Learning-Projects/blob/master/Intel_image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.6.20)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-be72df5b-abf1-49da-936c-7a6e0ad85ac2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be72df5b-abf1-49da-936c-7a6e0ad85ac2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"boss0ayush","key":"1fa540a28ee73b9f1504169bfda092c7"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d puneet6060/intel-image-classification
# Out:
# Downloading intel-image-classification.zip to /content
#  97% 337M/346M [00:08<00:00, 46.8MB/s]
# 100% 346M/346M [00:08<00:00, 43.3MB/s]

# %%
# !unzip intel-image-classification.zip

# %%
import tensorflow.keras.layers as Layers
import tensorflow.keras.activations as Actications
import tensorflow.keras.models as Models
import tensorflow.keras.optimizers as Optimizer
import tensorflow.keras.metrics as Metrics
import tensorflow.keras.utils as Utils
from keras.utils.vis_utils import model_to_dot
import os
import matplotlib.pyplot as plot
import cv2
import numpy as np
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix as CM
from random import randint
from IPython.display import SVG
import matplotlib.gridspec as gridspec
from keras.models import Sequential, Model
from keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input, Conv2D, Activation, MaxPooling2D
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
print(os.listdir())
# Out:
# ['.config', 'seg_train', 'seg_test', 'seg_pred', 'intel-image-classification.zip', 'kaggle.json', 'sample_data']

# %%
def get_images(directory):
    Images = []
    Labels = []  # 0 for Building , 1 for forest, 2 for glacier, 3 for mountain, 4 for Sea , 5 for Street
    label = 0
    
    for labels in os.listdir(directory): #Main Directory where each class label is present as folder name.
        if labels == 'glacier': #Folder contain Glacier Images get the '2' class label.
            label = 2
        elif labels == 'sea':
            label = 4
        elif labels == 'buildings':
            label = 0
        elif labels == 'forest':
            label = 1
        elif labels == 'street':
            label = 5
        elif labels == 'mountain':
            label = 3
        
        for image_file in os.listdir(directory+labels): #Extracting the file name of the image from Class Label folder
            image = cv2.imread(directory+labels+r'/'+image_file) #Reading the image (OpenCV)
            image = cv2.resize(image,(150,150)) #Resize the image, Some images are different sizes. (Resizing is very Important)
            Images.append(image)
            Labels.append(label)
    
    return shuffle(Images,Labels,random_state=817328462) #Shuffle the dataset you just prepared.

def get_classlabel(class_code):
    labels = {2:'glacier', 4:'sea', 0:'buildings', 1:'forest', 5:'street', 3:'mountain'}
    
    return labels[class_code]

# %%
Images, Labels = get_images('./seg_train/seg_train/') #Extract the training images from the folders.

Images = np.array(Images) #converting the list of images to numpy array.
Labels = np.array(Labels)

# %%
print("Shape of Images:",Images.shape)
print("Shape of Labels:",Labels.shape)
# Out:
# Shape of Images: (14034, 150, 150, 3)
# Shape of Labels: (14034,)

# %%
f,ax = plot.subplots(5,5) 
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
    for j in range(0,5,1):
        rnd_number = randint(0,len(Images))
        ax[i,j].imshow(Images[rnd_number])
        ax[i,j].set_title(get_classlabel(Labels[rnd_number]))
        ax[i,j].axis('off')

# %%
'''# number of possible label values
nb_classes = 6

# Initialising the CNN
model = Sequential()

# 1 - Convolution
model.add(Conv2D(64,(3,3), padding='same', input_shape=(150, 150,3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 2nd Convolution layer
model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 3rd Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 4th Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(nb_classes, activation='softmax'))

opt = Adam(lr=0.0001)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
'''
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 150, 150, 64)      1792
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 150, 150, 64)      256
# _________________________________________________________________
# activation_1 (Activation)    (None, 150, 150, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 75, 75, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 128)       204928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 75, 75, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 75, 75, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 37, 37, 512)       590336
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 37, 37, 512)       2048
# _________________________________________________________________
# activation_3 (Activation)    (None, 37, 37, 512)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 18, 18, 512)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 18, 18, 512)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 18, 18, 512)       2359808
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 18, 18, 512)       2048
# _________________________________________________________________
# activation_4 (Activation)    (None, 18, 18, 512)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 9, 9, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 9, 9, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 41472)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               10617088
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 3078
# =================================================================
# Total params: 13,916,550
# Trainable params: 13,912,582
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
# model from kaggle
model = Models.Sequential()

model.add(Layers.Conv2D(200,kernel_size=(3,3),activation='relu',input_shape=(150,150,3)))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(140,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(100,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(50,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Flatten())
model.add(Layers.Dense(180,activation='relu'))
model.add(Layers.Dense(100,activation='relu'))
model.add(Layers.Dense(50,activation='relu'))
model.add(Layers.Dropout(rate=0.5))
model.add(Layers.Dense(6,activation='softmax'))

model.compile(optimizer=Optimizer.Adam(lr=0.0001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 148, 148, 200)     5600
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 146, 146, 180)     324180
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 29, 29, 180)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 27, 27, 180)       291780
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 25, 25, 140)       226940
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 23, 23, 100)       126100
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 21, 21, 50)        45050
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 4, 50)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 180)               144180
# _________________________________________________________________
# dense_13 (Dense)             (None, 100)               18100
# _________________________________________________________________
# dense_14 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 6)                 306
# =================================================================
# Total params: 1,187,286
# Trainable params: 1,187,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
trained = model.fit(Images,Labels,epochs=35,validation_split=0.30)
# Out:
# Epoch 1/35
# 307/307 [==============================] - 196s 638ms/step - loss: 1.6331 - accuracy: 0.3479 - val_loss: 1.1904 - val_accuracy: 0.5621
# Epoch 2/35
# 307/307 [==============================] - 190s 619ms/step - loss: 1.2244 - accuracy: 0.5167 - val_loss: 0.9651 - val_accuracy: 0.6371
# Epoch 3/35
# 307/307 [==============================] - 190s 618ms/step - loss: 1.0938 - accuracy: 0.5800 - val_loss: 0.8371 - val_accuracy: 0.7029
# Epoch 4/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.9743 - accuracy: 0.6424 - val_loss: 0.8836 - val_accuracy: 0.6497
# Epoch 5/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.8701 - accuracy: 0.6785 - val_loss: 0.7724 - val_accuracy: 0.7024
# Epoch 6/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.8035 - accuracy: 0.7182 - val_loss: 0.6972 - val_accuracy: 0.7378
# Epoch 7/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.7494 - accuracy: 0.7435 - val_loss: 0.5576 - val_accuracy: 0.7948
# Epoch 8/35
# 307/307 [==============================] - 190s 619ms/step - loss: 0.6857 - accuracy: 0.7664 - val_loss: 0.5629 - val_accuracy: 0.8060
# Epoch 9/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.6456 - accuracy: 0.7854 - val_loss: 0.5616 - val_accuracy: 0.8076
# Epoch 10/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.6048 - accuracy: 0.7982 - val_loss: 0.5294 - val_accuracy: 0.8114
# Epoch 11/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.5811 - accuracy: 0.8045 - val_loss: 0.4799 - val_accuracy: 0.8340
# Epoch 12/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.5403 - accuracy: 0.8140 - val_loss: 0.5171 - val_accuracy: 0.8205
# Epoch 13/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.5028 - accuracy: 0.8297 - val_loss: 0.4631 - val_accuracy: 0.8388
# Epoch 14/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.4742 - accuracy: 0.8425 - val_loss: 0.5345 - val_accuracy: 0.8148
# Epoch 15/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.4433 - accuracy: 0.8521 - val_loss: 0.5253 - val_accuracy: 0.8245
# Epoch 16/35
# 307/307 [==============================] - 190s 619ms/step - loss: 0.4076 - accuracy: 0.8640 - val_loss: 0.4817 - val_accuracy: 0.8345
# Epoch 17/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.3904 - accuracy: 0.8701 - val_loss: 0.5033 - val_accuracy: 0.8345
# Epoch 18/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.3587 - accuracy: 0.8802 - val_loss: 0.4773 - val_accuracy: 0.8430
# Epoch 19/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.3428 - accuracy: 0.8850 - val_loss: 0.5123 - val_accuracy: 0.8307
# Epoch 20/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.3065 - accuracy: 0.8964 - val_loss: 0.5074 - val_accuracy: 0.8437
# Epoch 21/35
# 307/307 [==============================] - 190s 619ms/step - loss: 0.2746 - accuracy: 0.9104 - val_loss: 0.6257 - val_accuracy: 0.8347
# Epoch 22/35
# 307/307 [==============================] - 190s 619ms/step - loss: 0.2612 - accuracy: 0.9097 - val_loss: 0.5752 - val_accuracy: 0.8312
# Epoch 23/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.2583 - accuracy: 0.9141 - val_loss: 0.5375 - val_accuracy: 0.8416
# Epoch 24/35
# 307/307 [==============================] - 190s 619ms/step - loss: 0.2174 - accuracy: 0.9286 - val_loss: 0.6166 - val_accuracy: 0.8314
# Epoch 25/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.2088 - accuracy: 0.9330 - val_loss: 0.6340 - val_accuracy: 0.8338
# Epoch 26/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.1902 - accuracy: 0.9389 - val_loss: 0.6693 - val_accuracy: 0.8440
# Epoch 27/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.1705 - accuracy: 0.9427 - val_loss: 0.6704 - val_accuracy: 0.8262
# Epoch 28/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.1543 - accuracy: 0.9475 - val_loss: 0.7911 - val_accuracy: 0.8371
# Epoch 29/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.1662 - accuracy: 0.9471 - val_loss: 0.7190 - val_accuracy: 0.8423
# Epoch 30/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.1423 - accuracy: 0.9548 - val_loss: 0.7110 - val_accuracy: 0.8316
# Epoch 31/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.1346 - accuracy: 0.9578 - val_loss: 0.7442 - val_accuracy: 0.8399
# Epoch 32/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.1341 - accuracy: 0.9599 - val_loss: 0.8174 - val_accuracy: 0.8407
# Epoch 33/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.1154 - accuracy: 0.9653 - val_loss: 0.8643 - val_accuracy: 0.8392
# Epoch 34/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.1067 - accuracy: 0.9641 - val_loss: 0.7971 - val_accuracy: 0.8371
# Epoch 35/35
# 307/307 [==============================] - 190s 618ms/step - loss: 0.0899 - accuracy: 0.9703 - val_loss: 0.9178 - val_accuracy: 0.8390

# %%
plot.plot(trained.history['accuracy'])
plot.plot(trained.history['val_accuracy'])
plot.title('Model accuracy')
plot.ylabel('Accuracy')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

# %%
test_images,test_labels = get_images('./seg_test/seg_test/')
test_images = np.array(test_images)
test_labels = np.array(test_labels)
model.evaluate(test_images,test_labels, verbose=1)
# Out:
# 94/94 [==============================] - 17s 181ms/step - loss: 0.8856 - accuracy: 0.8403
# [0.8855773210525513, 0.8403333425521851]

# %%
pred_images,no_labels = get_images('./seg_pred/')
pred_images = np.array(pred_images)
pred_images.shape
# Out:
# (7301, 150, 150, 3)

# %%
fig = plot.figure(figsize=(30, 30))
outer = gridspec.GridSpec(5, 5, wspace=0.2, hspace=0.2)

for i in range(25):
    inner = gridspec.GridSpecFromSubplotSpec(2, 1,subplot_spec=outer[i], wspace=0.1, hspace=0.1)
    rnd_number = randint(0,len(pred_images))
    pred_image = np.array([pred_images[rnd_number]])
    pred_class = get_classlabel(model.predict_classes(pred_image)[0])
    pred_prob = model.predict(pred_image).reshape(6)
    for j in range(2):
        if (j%2) == 0:
            ax = plot.Subplot(fig, inner[j])
            ax.imshow(pred_image[0])
            ax.set_title(pred_class)
            ax.set_xticks([])
            ax.set_yticks([])
            fig.add_subplot(ax)
        else:
            ax = plot.Subplot(fig, inner[j])
            ax.bar([0,1,2,3,4,5],pred_prob)
            fig.add_subplot(ax)


fig.show()
# Out:
# WARNING:tensorflow:From <ipython-input-35-26ed54e093ba>:8: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
